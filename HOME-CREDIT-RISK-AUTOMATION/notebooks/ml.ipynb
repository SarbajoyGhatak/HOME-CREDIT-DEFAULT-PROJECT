# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/WORK/PROJECTS/HOME-CREDIT-RISK-AUTOMATION/data/clean/final_credit_risk_dataset.csv')

# %%
df.shape
# Out:
# (307511, 66)

# %%
df["DAYS_REGISTRATION"] = df["DAYS_REGISTRATION"].abs()
df["DAYS_ID_PUBLISH"] = df["DAYS_ID_PUBLISH"].abs()
df["DAYS_BIRTH"] = df["DAYS_BIRTH"].abs()
df["DAYS_EMPLOYED"] = df["DAYS_EMPLOYED"].abs()

# %%
df.head()
# Out:
#    target  CNT_FAM_MEMBERS  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# 0       1              1.0        9461            637             3648.0
# 1       0              2.0       16765           1188             1186.0
# 2       0              1.0       19046            225             4260.0
# 3       0              2.0       19005           3039             9833.0
# 4       0              1.0       19932           3038             4311.0
#
#    DAYS_ID_PUBLISH  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0             2120          202500.0    406597.5      24700.5
# 1              291          270000.0   1293502.5      35698.5
# 2             2531           67500.0    135000.0       6750.0
# 3             2437          135000.0    312682.5      29686.5
# 4             3458          121500.0    513000.0      21865.5
#
#    AMT_GOODS_PRICE  ...  NAME_INCOME_TYPE_Commercial associate  \
# 0         351000.0  ...                                  False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 66 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   target                                             307511 non-null  int64
#  1   CNT_FAM_MEMBERS                                    307509 non-null  float64
#  2   DAYS_BIRTH                                         307511 non-null  int64
#  3   DAYS_EMPLOYED                                      307511 non-null  int64
#  4   DAYS_REGISTRATION                                  307511 non-null  float64
#  5   DAYS_ID_PUBLISH                                    307511 non-null  int64
#  6   AMT_INCOME_TOTAL                                   307511 non-null  float64
#  7   AMT_CREDIT                                         307511 non-null  float64
# ...

# %% [markdown]
# creating target and features column and seperating them

# %%
x = df.drop("target", axis=1)
y = df["target"]

# %% [markdown]
# train test split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %% [markdown]
# inf or zero conversion

# %%
np.isinf(x_train).sum().sum()
# Out:
# np.int64(1)

# %%
x_train = x_train.replace([np.inf, -np.inf], np.nan)
x_test = x_test.replace([np.inf, -np.inf], np.nan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x_train = x_train.replace([np.inf, -np.inf], np.nan)
#       2 x_test = x_test.replace([np.inf, -np.inf], np.nan)
#
# NameError: name 'x_train' is not defined

# %%
x_train = x_train.fillna(x_train.median())
x_test = x_test.fillna(x_test.median())

# %% [markdown]
# feature scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# %% [markdown]
# training the model for logistic regression

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(class_weight="balanced")
model.fit(X_train_scaled, y_train)
# Out:
# c:\WORK\PROJECTS\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(class_weight='balanced')

# %% [markdown]
# predction and score

# %%
y_pred = model.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Accuracy:", accuracy_score(y_test, y_pred))

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.6946653008796319
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.70      0.81     56538
#            1       0.16      0.68      0.27      4965
#
#     accuracy                           0.69     61503
#    macro avg       0.56      0.69      0.54     61503
# weighted avg       0.90      0.69      0.76     61503
#
#
# Confusion Matrix:
#
# [[39325 17213]
#  [ 1566  3399]]

# %% [markdown]
# creating multiple models to build a ensemble model for better scores

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Gradient Boosting
model_gb = GradientBoostingClassifier(
    n_estimators=150,
    learning_rate=0.05,
    random_state=42
)


# Random Forest
model_rf = RandomForestClassifier(
    n_estimators=200,
    max_depth=8,
    class_weight="balanced",
    random_state=42
)

# Decision Tree
model_dt = DecisionTreeClassifier(
    max_depth=6,
    class_weight="balanced",
    random_state=42
)

# %%
np.isinf(x_train).sum().sum()
# Out:
# np.int64(0)

# %%
x_train = x_train.replace([np.inf, -np.inf], np.nan)
x_test = x_test.replace([np.inf, -np.inf], np.nan)

# fill missing values using median
x_train = x_train.fillna(x_train.median())
x_test = x_test.fillna(x_test.median())

# %%
# Random Forest
model_rf.fit(x_train, y_train)

# Gradient Boosting
model_gb.fit(x_train, y_train)

# Decision Tree
model_dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=6, random_state=42)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# Feature selection

# %%
import pandas as pd

feature_importance = pd.DataFrame({
    "Feature": x_train.columns,
    "Importance": model_rf.feature_importances_
})

feature_importance = feature_importance.sort_values(by="Importance", ascending=False)

print(feature_importance.head(50))
# Out:
#                                               Feature  Importance
# 42                                     ext_source_avg    0.293845
# 41                                       EXT_SOURCE_3    0.131194
# 40                                       EXT_SOURCE_2    0.118848
# 2                                       DAYS_EMPLOYED    0.047426
# 39                                       EXT_SOURCE_1    0.045109
# 19                             bureau_avg_days_credit    0.036382
# 11                                 credit_goods_ratio    0.029574
# 21                           bureau_debt_credit_ratio    0.025910
# 1                                          DAYS_BIRTH    0.024481
# 12                                   payment_capacity    0.020721
# 37                                approval_percentage    0.016675
# 27                                 late_payment_count    0.013494
# 38                        application_to_credit_ratio    0.012752
# ...

# %%
eature_importance = pd.DataFrame({
    "Feature": x_train.columns,
    "Importance": model_rf.feature_importances_
})

feature_importance = feature_importance.sort_values(by="Importance", ascending=False)

print(feature_importance.head(20))
# Out:
#                                               Feature  Importance
# 42                                     ext_source_avg    0.293845
# 41                                       EXT_SOURCE_3    0.131194
# 40                                       EXT_SOURCE_2    0.118848
# 2                                       DAYS_EMPLOYED    0.047426
# 39                                       EXT_SOURCE_1    0.045109
# 19                             bureau_avg_days_credit    0.036382
# 11                                 credit_goods_ratio    0.029574
# 21                           bureau_debt_credit_ratio    0.025910
# 1                                          DAYS_BIRTH    0.024481
# 12                                   payment_capacity    0.020721
# 37                                approval_percentage    0.016675
# 27                                 late_payment_count    0.013494
# 38                        application_to_credit_ratio    0.012752
# ...

# %%
important_features = feature_importance[
    feature_importance["Importance"] > 0.005
]["Feature"]

X_train_selected = x_train[important_features]
X_test_selected = x_test[important_features]

# %%
model_rf.fit(X_train_selected, y_train)
model.fit(X_train_selected, y_train)
model_dt.fit(X_train_selected, y_train)
# Out:
# c:\WORK\PROJECTS\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# DecisionTreeClassifier(class_weight='balanced', max_depth=6, random_state=42)

# %%
# Random Forest
y_pred_rf = model_rf.predict(X_test_selected)

# Gradient Boosting
y_pred_lr = model.predict(X_test_selected)

# Decision Tree
y_pred_dt = model_dt.predict(X_test_selected)

# %%
print("Logistic Regression")

print("Accuracy:", accuracy_score(y_test, y_pred_lr))

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred_lr))

print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, y_pred_lr))
# Out:
# Logistic Regression
# Accuracy: 0.6031738289189146
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.61      0.74     56538
#            1       0.11      0.56      0.18      4965
#
#     accuracy                           0.60     61503
#    macro avg       0.53      0.58      0.46     61503
# weighted avg       0.87      0.60      0.69     61503
#
#
# Confusion Matrix:
#
# [[34336 22202]
#  [ 2204  2761]]

# %%
print("Decision Tree")

print("Accuracy:", accuracy_score(y_test, y_pred_dt))

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred_dt))

print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, y_pred_dt))
# Out:
# Decision Tree
# Accuracy: 0.6583256101328391
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.66      0.78     56538
#            1       0.15      0.69      0.25      4965
#
#     accuracy                           0.66     61503
#    macro avg       0.55      0.67      0.51     61503
# weighted avg       0.89      0.66      0.74     61503
#
#
# Confusion Matrix:
#
# [[37075 19463]
#  [ 1551  3414]]

# %%
print("Random Forest")

print("Accuracy:", accuracy_score(y_test, y_pred_rf))

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred_rf))

print("\nConfusion Matrix:\n")
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# Random Forest
# Accuracy: 0.722338747703364
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.73      0.83     56538
#            1       0.17      0.64      0.27      4965
#
#     accuracy                           0.72     61503
#    macro avg       0.57      0.68      0.55     61503
# weighted avg       0.89      0.72      0.78     61503
#
#
# Confusion Matrix:
#
# [[41253 15285]
#  [ 1792  3173]]

# %%
prob_rf = model_rf.predict_proba(X_test_selected)[:,1]
prob_dt = model_dt.predict_proba(X_test_selected)[:,1]
prob_lr = model.predict_proba(X_test_selected)[:,1]

# %%
final_prob = (
    0.4 * prob_lr +
    0.4 * prob_rf +
    0.2 * prob_dt
)

# %%
risk_score = (1 - final_prob) * 10
risk_score = risk_score.round(2)

# %%
print(risk_score[:10])
# Out:
# [5.93 5.34 4.52 5.81 5.22 4.32 8.04 7.49 2.93 6.19]

# %%
def risk_band(score):
    if score >= 8:
        return "Very Safe"
    elif score >= 6:
        return "Safe"
    elif score >= 5:
        return "Medium Risk"
    elif score >= 3:
        return "Risky"
    else:
        return "Very Risky"

risk_df["Risk Category"] = risk_df["Risk Score (out of 10)"].apply(risk_band)

risk_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 13
#      10     else:
#      11         return "Very Risky"
# ---> 13 risk_df["Risk Category"] = risk_df["Risk Score (out of 10)"].apply(risk_band)
#      15 risk_df.head(10)
#
# NameError: name 'risk_df' is not defined
